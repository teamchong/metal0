# %%
# Cell 1: Basic computation
result = 55
print(result)

# %% [markdown]
# # PyAOT Notebook Demo
#
# This demonstrates PyAOT can compile and execute Jupyter notebook cells.

# %%
# Cell 2: Use result from previous cell (state sharing)
doubled = result * 2
print(doubled)

# %%
# Cell 3: List operations
numbers = [1, 2, 3, 4, 5]
total = 0
for num in numbers:
    total = total + num
print(total)

# %%
# Cell 4: String operations
text = "PyAOT compiles notebooks!"
print(text)
