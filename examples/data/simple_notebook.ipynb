# %%
# Cell 1: Basic arithmetic
x = 10
y = 20
print(x + y)

# %% [markdown]
# # Simple Notebook Test
#
# This notebook demonstrates PyAOT can compile Jupyter notebooks.

# %%
# Cell 2: State sharing
z = x * y
print(z)

# %%
# Cell 3: String operations
message = "Hello from PyAOT!"
print(message)
