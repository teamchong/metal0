# %%
# Cell 1: Magic commands should be filtered out
# %matplotlib inline
# %%time
x = 100
print(x)

# %%
# Cell 2: IPython.display should be filtered
from IPython.display import display, HTML
y = x * 2
print(y)

# %%
# Cell 3: display() should become print()
result = y + 50
display(result)

# %%
# Cell 4: Regular Python code
total = result + 10
print(total)
